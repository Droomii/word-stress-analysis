# %%
import parselmouth

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import interpolate

# %%
sns.set() # Use seaborn's default style to make attractive graphs
plt.rcParams['figure.dpi'] = 100 # Show nicely large images in this notebook

# %%
snd = parselmouth.Sound("sample.wav")
snd2 = parselmouth.Sound("sample2.wav")

# %%
plt.plot(snd.xs(), snd.values.T)
plt.xlim([snd.xmin, snd.xmax])
plt.xlabel("time [s]")
plt.ylabel("amplitude")
plt.show() # or plt.savefig("sound.png"), or plt.savefig("sound.pdf")

# %%
def draw_spectrogram(spectrogram, dynamic_range=70):
    X, Y = spectrogram.x_grid(), spectrogram.y_grid()
    sg_db = 10 * np.log10(spectrogram.values)
    plt.pcolormesh(X, Y, sg_db, vmin=sg_db.max() - dynamic_range, cmap='afmhot')
    plt.ylim([spectrogram.ymin, spectrogram.ymax])
    plt.xlabel("time [s]")
    plt.ylabel("frequency [Hz]")

def draw_intensity(intensity):
    plt.plot(intensity.xs(), intensity.values.T, linewidth=3, color='w')
    plt.plot(intensity.xs(), intensity.values.T, linewidth=1)
    plt.grid(False)
    plt.ylim(0)
    plt.ylabel("intensity [dB]")

# %%
intensity = snd.to_intensity()
spectrogram = snd.to_spectrogram()
plt.figure()
draw_spectrogram(spectrogram)
plt.twinx()
draw_intensity(intensity)
plt.xlim([snd.xmin, snd.xmax])
plt.show()
# Out:
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log10
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#intensity quantile of 25
intensity_q25 = np.quantile(intensity.values, 0.25)



xs_normalized = pitch.xs() / np.max(pitch.xs())
xs_normalized
len(pitch.xs())
# Out:
# 304

# %%
#get start and end pitch value index
pitch_values = pitch2.selected_array['frequency']
pitch_values[pitch_values==0] = np.nan
pitch_start_index = np.where(~np.isnan(pitch_values))[0][0]
pitch_end_index = np.where(~np.isnan(pitch_values))[0][-1]

# get normalized time
xs = pitch2.xs()[pitch_start_index:pitch_end_index+1]

# trim pitch values by start and end
trimmed_pitch_values = pitch_values[pitch_start_index:pitch_end_index+1]

# divide pitch values by pitch median(to get relational values)
trimmed_pitch_values /= np.nanmedian(trimmed_pitch_values)

# set xs min to zero
xs -= np.min(xs)
normalized_xs = xs / np.max(xs)
np.nanstd(trimmed_pitch_values) * 100
# Out:
# 8.034314526049114

# %%
def fill_nan(A):
    '''
    interpolate to fill nan values
    '''
    inds = np.arange(A.shape[0])
    good = np.where(np.isfinite(A))
    f = interpolate.interp1d(inds[good], A[good],bounds_error=False)
    B = np.where(np.isfinite(A),A,f(inds))
    return B

# %%
len(trimmed_pitch_values)
# Out:
# 91

# %%
def draw_pitch(pitch, color='b'):
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    pitch_values = pitch.selected_array['frequency']
    pitch_values[pitch_values==0] = np.nan
    
    # remove outlier
    median = np.nanmedian(pitch_values)
    low_outlier = median / 2
    high_outlier = median * 2
    pitch_values[pitch_values > high_outlier] = np.nan
    pitch_values[pitch_values < low_outlier] = np.nan
    
    #get start and end pitch value index
    pitch_start_index = np.where(~np.isnan(pitch_values))[0][0]
    pitch_end_index = np.where(~np.isnan(pitch_values))[0][-1]
    
    # trim pitch values by start and end
    trimmed_pitch_values = pitch_values[pitch_start_index:pitch_end_index+1]
    
    
    
    # divide pitch values by pitch median(to get relational values)
    trimmed_pitch_values /= np.nanmedian(trimmed_pitch_values)
    
    # normalize pitch values between 0 to 1
    #trimmed_pitch_values -= np.nanmin(trimmed_pitch_values)
    #trimmed_pitch_values /= np.nanmax(trimmed_pitch_values)
    
    # linear interpolation of nans
    # trimmed_pitch_values = fill_nan(trimmed_pitch_values)
    
    
    # trim time and normalize
    xs = pitch.xs()[pitch_start_index:pitch_end_index+1]
    xs -= np.min(xs)
    normalized_xs = xs / np.max(xs)
    
    plt.plot(normalized_xs, trimmed_pitch_values, 'o', markersize=5, color='w')
    plt.plot(normalized_xs, trimmed_pitch_values, 'o', markersize=2, color=color)
    plt.plot(normalized_xs, trimmed_pitch_values, '-', markersize=2, color=color)
    plt.ylim(0.25, 1.75)
    
    plt.ylabel("fundamental frequency [Hz]")

# %%
# get pitch and smoothens pitch
pitch = snd.to_pitch_ac(very_accurate=False, silence_threshold=0.1, voicing_threshold=0.50).smooth()
pitch2 = snd2.to_pitch_ac(very_accurate=False, silence_threshold=0.1, voicing_threshold=0.50).smooth()

# %%
# If desired, pre-emphasize the sound fragment before calculating the spectrogram
pre_emphasized_snd = snd.copy()
pre_emphasized_snd.pre_emphasize()

pre_emphasized_snd2 = snd2.copy()
pre_emphasized_snd2.pre_emphasize()

spectrogram = pre_emphasized_snd.to_spectrogram(window_length=0.03, maximum_frequency=8000)

# %%
# get first pitch and last pitch

# %%
def draw_delta(pitch, color='b'):
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    pitch_values = pitch.selected_array['frequency']
    pitch_values[pitch_values==0] = np.nan
    
    # remove outlier
    median = np.nanmedian(pitch_values)
    low_outlier = median / 2
    high_outlier = median * 2
    pitch_values[pitch_values > high_outlier] = np.nan
    pitch_values[pitch_values < low_outlier] = np.nan
    
    #get start and end pitch value index
    pitch_start_index = np.where(~np.isnan(pitch_values))[0][0]
    pitch_end_index = np.where(~np.isnan(pitch_values))[0][-1]
    
    # trim pitch values by start and end
    trimmed_pitch_values = pitch_values[pitch_start_index:pitch_end_index+1]
    
    
    
    # divide pitch values by pitch median(to get relational values)
    trimmed_pitch_values /= np.nanmedian(trimmed_pitch_values)
    
    # normalize pitch values between 0 to 1
    trimmed_pitch_values -= np.nanmin(trimmed_pitch_values)
    trimmed_pitch_values /= np.nanmax(trimmed_pitch_values)
    
    # linear interpolation of nans
    trimmed_pitch_values = fill_nan(trimmed_pitch_values)
    
    #forward fill nans
    '''
    for i in range(len(trimmed_pitch_values)):
        if np.isnan(trimmed_pitch_values[i]):
            trimmed_pitch_values[i] = trimmed_pitch_values[i-1]
    '''
    
    # trim time and normalize
    xs = pitch.xs()[pitch_start_index:pitch_end_index+1]
    xs -= np.min(xs)
    normalized_xs = xs / np.max(xs)
    
    pitch_diff = np.diff(trimmed_pitch_values)
    
    plt.plot(normalized_xs[1:], pitch_diff, 'o', markersize=5, color='w')
    plt.plot(normalized_xs[1:], pitch_diff, 'o', markersize=2, color=color)
    plt.plot(normalized_xs[1:], pitch_diff, '-', markersize=2, color=color)
    
    # draw stress region 
    fig, ax = plt.subplots()
    
    ax.fill_between(normalized_xs[1:], 0, 1, where=pitch_diff > 0,
                color='green', alpha=0.5, transform=ax.get_xaxis_transform())
    plt.ylim(-0.2, 0.2)
    
    plt.ylabel("fundamental frequency [Hz]")

# %%
def draw_stress(pitch, color='b'):
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    pitch_values = pitch.selected_array['frequency']
    pitch_values[pitch_values==0] = np.nan
    
    # remove outlier
    median = np.nanmedian(pitch_values)
    low_outlier = median / 2
    high_outlier = median * 2
    pitch_values[pitch_values > high_outlier] = np.nan
    pitch_values[pitch_values < low_outlier] = np.nan
    
    #get start and end pitch value index
    pitch_start_index = np.where(~np.isnan(pitch_values))[0][0]
    pitch_end_index = np.where(~np.isnan(pitch_values))[0][-1]
    
    # trim pitch values by start and end
    trimmed_pitch_values = pitch_values[pitch_start_index:pitch_end_index+1]
    
    
    
    # divide pitch values by pitch median(to get relational values)
    trimmed_pitch_values /= np.nanmedian(trimmed_pitch_values)
    
    # normalize pitch values between 0 to 1
    trimmed_pitch_values -= np.nanmin(trimmed_pitch_values)
    trimmed_pitch_values /= np.nanmax(trimmed_pitch_values)
    
    # linear interpolation of nans
    trimmed_pitch_values = fill_nan(trimmed_pitch_values)
    
    # trim time and normalize
    xs = pitch.xs()[pitch_start_index:pitch_end_index+1]
    xs -= np.min(xs)
    normalized_xs = xs / np.max(xs)
    
    pitch_diff = np.diff(trimmed_pitch_values)
    
    # draw stress region 
    fig, ax = plt.subplots()
    
    ax.fill_between(normalized_xs[1:]+0.05, 0, 1, where=pitch_diff > 0,
                color=color, alpha=0.3, transform=ax.get_xaxis_transform())

    plt.grid(True)
    plt.xlim(0, 1)
    
    plt.ylabel("fundamental frequency [Hz]")

# %%
plt.figure()
# draw_spectrogram(spectrogram)
draw_stress(pitch)
draw_stress(pitch2, 'r')
draw_pitch(pitch)
draw_pitch(pitch2, 'r')


# plt.xlim([snd.xmin, snd.xmax])
# plt.xlim([first_pitch, last_pitch+0.2])
plt.show()
# Out:
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %%
plt.figure()
plt.twinx()
draw_delta(pitch)
snd3 = parselmouth.Sound("sample3.wav")
pitch3 = snd3.to_pitch_ac(very_accurate=False, silence_threshold=0.1, voicing_threshold=0.50).smooth()
draw_delta(pitch2, color='r')
plt.hlines(0, 0, 1, colors='g')

plt.show()
# Out:
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in greater
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\data-08\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %%
def draw_formant(formant):
    # Extract selected pitch contour, and
    # replace unvoiced samples by NaN to not plot
    pitch_values = pitch.selected_array['frequency']
    pitch_values[pitch_values==0] = np.nan
    
    # remove outlier
    median = np.nanmedian(pitch_values)
    low_outlier = median / 2
    high_outlier = median * 2
    pitch_values[pitch_values > high_outlier] = np.nan
    pitch_values[pitch_values < low_outlier] = np.nan
    
    plt.plot(pitch.xs(), pitch_values, 'o', markersize=5, color='w')
    plt.plot(pitch.xs(), pitch_values, 'o', markersize=2)
    plt.plot(pitch.xs(), pitch_values, '-', markersize=2, color='b')
    plt.grid(False)
    plt.ylim(np.nanmin(pitch_values)-10, np.nanmax(pitch_values)+10)
    
    plt.ylabel("fundamental frequency [Hz]")

# %%
formant = snd.to_formant_burg()

# %%
formants = {}
for i in formant.ts():
    formant_values = []
    k = 1
    while not np.isnan(formant.get_bandwidth_at_time(k,i)):
        formant_values.append(formant.get_bandwidth_at_time(k, i))
        k += 1
    formants[i] = formant_values
formants
# Out:
# {0.02718749999999981: [416.3254572920485, 795.0416033337169, 683.234582181142],
#  0.03343749999999981: [39.158897628591816,
#   953.9048580170088,
#   1097.0749655579732,
#   470.5792973391824],
#  0.039687499999999806: [62.93653592945932,
#   575.1682218928552,
#   963.288525482927,
#   426.9922977452075],
#  0.04593749999999981: [110.89902396107784,
#   520.1370645945744,
#   914.1413613416877,
#   501.96722084734085],
#  0.05218749999999981: [116.70965092259557,
#   716.0744977976584,
#   570.1563648818376,
#   415.438587675034],
#  0.05843749999999981: [64.89500066889572,
#   516.9125979497652,
#   913.117540216352,
#   495.7952391280108],
#  0.06468749999999981: [40.45644180182072,
#   275.4431256447628,
#   282.22951947942335,
#   214.20689493740804,
#   614.6321431714389],
#  0.07093749999999982: [73.6533074135717,
#   125.71336724493108,
#   181.295850083452,
#   190.60042407035584,
#   373.84799215789167],
#  0.07718749999999981: [88.0190995635568,
#   129.14038262465007,
#   250.93823463221565,
#   209.90315394084377,
#   520.258012222176],
#  0.0834374999999998: [58.72700335525791,
#   117.42737001487663,
#   219.28519542055886,
#   262.1154282646613,
#   695.9154245263451],
#  0.08968749999999981: [35.51022242014301,
#   66.00430007368368,
#   105.54455485556501,
#   193.79429632984193,
#   1151.1840512823796],
#  0.09593749999999981: [29.906899007301327,
#   50.39024813861991,
#   70.10933821264322,
#   133.13066771503225],
#  0.10218749999999982: [25.006318844999587,
#   63.22368796774345,
#   70.00561277702535,
#   208.8835018851768],
#  0.10843749999999981: [23.291316085145283,
#   73.80056341098447,
#   118.09845104037917,
#   281.6028279205452],
#  0.11468749999999982: [25.976513001174865,
#   110.88843667555788,
#   138.20894815192904,
#   368.46268788786074],
#  0.12093749999999981: [31.516252826547017,
#   179.29796196894978,
#   197.36429575813648,
#   524.2266972003632],
#  0.12718749999999981: [38.40801970839847,
#   177.15777533640204,
#   132.718061945823,
#   617.2543820691355],
#  0.13343749999999982: [46.43278148032745,
#   223.23864099677462,
#   170.07028683045252,
#   588.128373809253],
#  0.1396874999999998: [56.88653362118788,
#   190.22507644195002,
#   215.07380324936204,
#   578.0308886893223],
#  0.14593749999999983: [71.20461556337645,
#   173.71811471017108,
#   346.99570450901064,
#   669.983171188197],
#  0.1521874999999998: [98.39914468920983,
#   145.91748535808117,
#   499.8967467042353,
#   395.5873395591554,
#   483.6584039660773],
#  0.15843749999999981: [253.24469427447391,
#   85.54706056478129,
#   561.3377354180029,
#   388.8238019299465,
#   330.5864795343516],
#  0.16468749999999982: [158.17659402557678,
#   612.1160813366645,
#   707.1075902399095,
#   507.9558341511159],
#  0.17093749999999983: [233.95425162998086,
#   617.731746033968,
#   616.8121892478517,
#   295.79112406794593],
#  0.17718749999999983: [240.6155515421818,
#  1.5771875: [42.369814725170556, 4.4518428203961165, 1.9703401265843241],
#  1.5834375: [44.15623477038981, 4.9307675223076375, 2.0009980240084224],
#  1.5896874999999997: [45.82896165549243, 5.428547897546238, 2.027800268195212],
#  1.5959374999999998: [47.43034670849257,
#   5.958276869430946,
#   2.0519716048921257],
#  1.6021874999999999: [48.93379522789813,
#   6.5114787724957335,
#   2.0734672794208473],
#  1.6084375: [50.34045892968237, 7.086779369960017, 2.092641396353358],
#  1.6146875: [51.63411888595401, 7.673831807994485, 2.109610961453535],
#  1.6209374999999997: [52.85680146619773,
#   8.288561439695618,
#   2.1251408218187935],
#  1.6271874999999998: [53.99535064009293,
#   8.921339304122629,
#   2.1391677402160383],
#  1.6334374999999999: [55.054547657272984,
#   9.570792926613127,
#   2.1519018523019224],
#  1.6396875: [56.02444453788947, 10.225606362496405, 2.163390312156379],
#  1.6459375: [56.94023988120044, 10.904033563852737, 2.174073027751789],
#  1.6521874999999997: [57.792630772834926,
#   11.59539085122166,
#   2.1838822363885075],
#  1.6584374999999998: [58.58527451064798, 12.29807920422509, 2.192964852311457],
#  1.6646874999999999: [59.3126259296861, 13.000467665378366, 2.201284413153007],
#  1.6709375: [60.00084721683327, 13.722068827783227, 2.209146187237002],
#  1.6771875: [60.64237853754393, 14.451295461618844, 2.216496325498026],
#  1.6834374999999997: [61.240638278403615,
#   15.186784706454564,
#   2.2233989510754872],
#  1.6896874999999998: [61.79145189017713,
#   15.916577726053388,
#   2.2297990252882967],
#  1.6959374999999999: [62.313923859360955,
#   16.660768164648594,
#   2.2359314602023157],
#  1.7021875: [62.80246223029306, 17.407116731338725, 2.241750763223407],
#  1.7084375: [502.2176699911683,
#   477.7342026955016,
#   269.616802716435,
#   2.1055513904368133],
#  1.7146874999999997: [605.83152413525, 699.2229861155139, 617.7817836182015],
#  1.7209374999999998: [489.30775951076805,
#   798.5349498430636,
#   868.4854765073727]}

# %%
plt.figure()
for k, v in formants.items():
    for i in v:
        plt.plot(k, i, 'o', markersize=2, color='b')
plt.ylim(0, 1000)
# Out:
# (0, 1000)

# %%
formant.ts()[0]
# Out:
# 0.02661458333333311

# %%
pitch_value = pitch.selected_array['frequency']

# %%
pitch_value[pitch_value==0.0] = np.nan

# %%
# median(ignore nan)
np.nanmedian(pitch_value)
# Out:
# 211.68456431802838

# %%
# q50
q25, q75 = np.nanpercentile(pitch_value, [25, 75])
q50 = np.nanpercentile(pitch_value, 50)
(q25, q75)
iqr = q75 - q25
iqr
# Out:
# 61.13978374667764

# %%
# outlier
low_outlier = q50 / 2
high_outlier = q50 * 2
pitch_value[pitch_value > high_outlier] = np.nan
pitch_value[pitch_value < low_outlier] = np.nan
# Out:
# C:\Users\DATALAB_3\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in greater
#   after removing the cwd from sys.path.
# C:\Users\DATALAB_3\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in less
#   """

# %%
high_outlier
# Out:
# 309.74873754467404

# %%
# mean(ignore nan)
np.nanmean(pitch_value)
# Out:
# 150.2621397051458

# %%
# max(ignore nan)
np.nanmax(pitch_value)
# Out:
# 242.69784955647253

# %%
# min(ignore nan)
np.nanmin(pitch_value)
# Out:
# 80.4272241456674
